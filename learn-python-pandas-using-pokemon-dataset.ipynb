# %% [markdown]
# **What is Pandas?**<br>
# The pandas package is the most important tool at the disposal of Data Scientists and Analysts working in Python today. The powerful machine learning and glamorous visualization tools may get all the attention, but pandas is the backbone of most data projects.

# %% [markdown]
# **Cheat sheet**<br>
# http://http://pandas.pydata.org/Pandas_Cheat_Sheet.pdf

# %% [markdown]
# **A set of lesson for new pandas users**<br>
# https://bitbucket.org/hrojas/learn-pandas/src/master

# %% [markdown]
# <img src="https://media.mnn.com/assets/images/2017/03/Panda-Eating-Bamboo-Stalk.jpg" width="700px"/>

# %% [markdown]
# **Import libraries**

# %%
import pandas as pd

# %% [markdown]
# **Read dataset**

# %%
df = pd.read_csv('../input/pokemon/Pokemon.csv')

# %% [markdown]
# **Print the dataset**

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True
#
# [800 rows x 13 columns]

# %% [markdown]
# **Count total rows**

# %%
print(str(len(df)))
# Out:
# 800

# %% [markdown]
# **Print first five row**

# %%
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# **Print last five rows**

# %%
df.tail(5)
# Out:
#        #                 Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 795  719              Diancie     Rock  Fairy    600  50     100      150
# 796  719  DiancieMega Diancie     Rock  Fairy    700  50     160      110
# 797  720  HoopaHoopa Confined  Psychic  Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic   Dark    680  80     160       60
# 799  721            Volcanion     Fire  Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True

# %% [markdown]
# **Read data size**

# %%
df.shape
# Out:
# (800, 13)

# %% [markdown]
# **Read headers**

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %% [markdown]
# **Check the types of each column**

# %%
df.dtypes
# Out:
# #              int64
# Name          object
# Type 1        object
# Type 2        object
# Total          int64
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Generation     int64
# Legendary       bool
# dtype: object

# %% [markdown]
# **Read each Columns**

# %%
df['Name']
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %% [markdown]
# **Read first five names**

# %%
df['Name'][0:5]
# Out:
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# Name: Name, dtype: object

# %%
df[['Name', 'Generation', 'Speed']]
# Out:
#                       Name  Generation  Speed
# 0                Bulbasaur           1     45
# 1                  Ivysaur           1     60
# 2                 Venusaur           1     80
# 3    VenusaurMega Venusaur           1     80
# 4               Charmander           1     65
# ..                     ...         ...    ...
# 795                Diancie           6     50
# 796    DiancieMega Diancie           6    110
# 797    HoopaHoopa Confined           6     70
# 798     HoopaHoopa Unbound           6     80
# 799              Volcanion           6     70
#
# [800 rows x 3 columns]

# %% [markdown]
# **Read each row**

# %%
df.iloc[1]
# Out:
# #                   2
# Name          Ivysaur
# Type 1          Grass
# Type 2         Poison
# Total             405
# HP                 60
# Attack             62
# Defense            63
# Sp. Atk            80
# Sp. Def            80
# Speed              60
# Generation          1
# Legendary       False
# Name: 1, dtype: object

# %%
df.iloc[543]
# Out:
# #                   486
# Name          Regigigas
# Type 1           Normal
# Type 2              NaN
# Total               670
# HP                  110
# Attack              160
# Defense             110
# Sp. Atk              80
# Sp. Def             110
# Speed               100
# Generation            4
# Legendary          True
# Name: 543, dtype: object

# %% [markdown]
# **Read multiple rows**

# %%
df.iloc[9:12]
# Out:
#     #       Name Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 9   7   Squirtle  Water    NaN    314  44      48       65       50       64
# 10  8  Wartortle  Water    NaN    405  59      63       80       65       80
# 11  9  Blastoise  Water    NaN    530  79      83      100       85      105
#
#     Speed  Generation  Legendary
# 9      43           1      False
# 10     58           1      False
# 11     78           1      False

# %% [markdown]
# **Read a specific a value**

# %%
df.iloc[10,5]
# Out:
# 59

# %%
df.iloc[9,2]
# Out:
# 'Water'

# %% [markdown]
# **Read rows using condition**

# %%
df.loc[df['Type 1'] == 'Water']
# Out:
#        #                     Name Type 1 Type 2  Total  HP  Attack  Defense  \
# 9      7                 Squirtle  Water    NaN    314  44      48       65
# 10     8                Wartortle  Water    NaN    405  59      63       80
# 11     9                Blastoise  Water    NaN    530  79      83      100
# 12     9  BlastoiseMega Blastoise  Water    NaN    630  79     103      120
# 59    54                  Psyduck  Water    NaN    320  50      52       48
# ..   ...                      ...    ...    ...    ...  ..     ...      ...
# 724  656                  Froakie  Water    NaN    314  41      56       40
# 725  657                Frogadier  Water    NaN    405  54      63       52
# 726  658                 Greninja  Water   Dark    530  72      95       67
# 762  692                Clauncher  Water    NaN    330  50      53       62
# 763  693                Clawitzer  Water    NaN    500  71      73       88
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 9         50       64     43           1      False
# 10        65       80     58           1      False
# 11        85      105     78           1      False
# 12       135      115     78           1      False
# 59        65       50     55           1      False
# ..       ...      ...    ...         ...        ...
# 724       62       44     71           6      False
# 725       83       56     97           6      False
# 726      103       71    122           6      False
# 762       58       63     44           6      False
# 763      120       89     59           6      False
#
# [112 rows x 13 columns]

# %% [markdown]
# **Read rows using multiple condition**

# %%
df.loc[(df['Type 1'] == 'Water') & (df['Type 2'] == 'Dark')]
# Out:
#        #                   Name Type 1 Type 2  Total  HP  Attack  Defense  \
# 141  130  GyaradosMega Gyarados  Water   Dark    640  95     155      109
# 347  318               Carvanha  Water   Dark    305  45      90       20
# 348  319               Sharpedo  Water   Dark    460  70     120       40
# 349  319  SharpedoMega Sharpedo  Water   Dark    560  70     140       70
# 374  342              Crawdaunt  Water   Dark    468  63     120       85
# 726  658               Greninja  Water   Dark    530  72      95       67
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 141       70      130     81           1      False
# 347       65       20     65           3      False
# 348       95       40     95           3      False
# 349      110       65    105           3      False
# 374       90       55     55           3      False
# 726      103       71    122           6      False

# %%
df.loc[(df['Type 1'] == 'Water') & (df['Type 2'] == 'Dark') & (df['HP'] > 60)]
# Out:
#        #                   Name Type 1 Type 2  Total  HP  Attack  Defense  \
# 141  130  GyaradosMega Gyarados  Water   Dark    640  95     155      109
# 348  319               Sharpedo  Water   Dark    460  70     120       40
# 349  319  SharpedoMega Sharpedo  Water   Dark    560  70     140       70
# 374  342              Crawdaunt  Water   Dark    468  63     120       85
# 726  658               Greninja  Water   Dark    530  72      95       67
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 141       70      130     81           1      False
# 348       95       40     95           3      False
# 349      110       65    105           3      False
# 374       90       55     55           3      False
# 726      103       71    122           6      False

# %%
array = ['Dark', 'Ghost', 'Ground']
df.loc[(df['Type 1'] == 'Fire') & df['Type 2'].isin(array)]
# Out:
#        #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 352  322                  Numel   Fire  Ground    305  60      60       40
# 353  323               Camerupt   Fire  Ground    460  70     100       70
# 354  323  CameruptMega Camerupt   Fire  Ground    560  70     120      100
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 352       65       45     35           3      False
# 353      105       75     40           3      False
# 354      145      105     20           3      False

# %%
array = ['Fire', 'Water', 'Rain']
df.loc[df['Type 1'].isin(array)]
# Out:
#        #                       Name Type 1  Type 2  Total  HP  Attack  \
# 4      4                 Charmander   Fire     NaN    309  39      52
# 5      5                 Charmeleon   Fire     NaN    405  58      64
# 6      6                  Charizard   Fire  Flying    534  78      84
# 7      6  CharizardMega Charizard X   Fire  Dragon    634  78     130
# 8      6  CharizardMega Charizard Y   Fire  Flying    634  78     104
# ..   ...                        ...    ...     ...    ...  ..     ...
# 735  667                     Litleo   Fire  Normal    369  62      50
# 736  668                     Pyroar   Fire  Normal    507  86      68
# 762  692                  Clauncher  Water     NaN    330  50      53
# 763  693                  Clawitzer  Water     NaN    500  71      73
# 799  721                  Volcanion   Fire   Water    600  80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 4         43       60       50     65           1      False
# 5         58       80       65     80           1      False
# 6         78      109       85    100           1      False
# 7        111      130       85    100           1      False
# 8         78      159      115    100           1      False
# ..       ...      ...      ...    ...         ...        ...
# 735       58       73       54     72           6      False
# 736       72      109       66    106           6      False
# 762       62       58       63     44           6      False
# 763       88      120       89     59           6      False
# 799      120      130       90     70           6       True
#
# [164 rows x 13 columns]

# %% [markdown]
# **Describing data**

# %%
df.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# 50%     70.000000   65.000000     3.00000
# 75%     90.000000   90.000000     5.00000
# max    230.000000  180.000000     6.00000

# %% [markdown]
# **Sorting data**

# %%
df.sort_values('Name')
# Out:
#        #                     Name   Type 1  Type 2  Total   HP  Attack  \
# 510  460                Abomasnow    Grass     Ice    494   90      92
# 511  460  AbomasnowMega Abomasnow    Grass     Ice    594   90     132
# 68    63                     Abra  Psychic     NaN    310   25      20
# 392  359                    Absol     Dark     NaN    465   65     130
# 393  359          AbsolMega Absol     Dark     NaN    565   65     150
# ..   ...                      ...      ...     ...    ...  ...     ...
# 632  571                  Zoroark     Dark     NaN    510   60     105
# 631  570                    Zorua     Dark     NaN    330   40      65
# 46    41                    Zubat   Poison  Flying    245   40      45
# 695  634                 Zweilous     Dark  Dragon    420   72      85
# 794  718         Zygarde50% Forme   Dragon  Ground    600  108     100
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 510       75       92       85     60           4      False
# 511      105      132      105     30           4      False
# 68        15      105       55     90           1      False
# 392       60       75       60     75           3      False
# 393       60      115       60    115           3      False
# ..       ...      ...      ...    ...         ...        ...
# 632       60      120       60    105           5      False
# 631       40       80       40     65           5      False
# 46        35       30       40     55           1      False
# 695       70       65       70     58           5      False
# 794      121       81       95     95           6       True
#
# [800 rows x 13 columns]

# %% [markdown]
# **Sorting data using multiple columns**

# %%
df.sort_values(['Name', 'HP', 'Generation'])
# Out:
#        #                     Name   Type 1  Type 2  Total   HP  Attack  \
# 510  460                Abomasnow    Grass     Ice    494   90      92
# 511  460  AbomasnowMega Abomasnow    Grass     Ice    594   90     132
# 68    63                     Abra  Psychic     NaN    310   25      20
# 392  359                    Absol     Dark     NaN    465   65     130
# 393  359          AbsolMega Absol     Dark     NaN    565   65     150
# ..   ...                      ...      ...     ...    ...  ...     ...
# 632  571                  Zoroark     Dark     NaN    510   60     105
# 631  570                    Zorua     Dark     NaN    330   40      65
# 46    41                    Zubat   Poison  Flying    245   40      45
# 695  634                 Zweilous     Dark  Dragon    420   72      85
# 794  718         Zygarde50% Forme   Dragon  Ground    600  108     100
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 510       75       92       85     60           4      False
# 511      105      132      105     30           4      False
# 68        15      105       55     90           1      False
# 392       60       75       60     75           3      False
# 393       60      115       60    115           3      False
# ..       ...      ...      ...    ...         ...        ...
# 632       60      120       60    105           5      False
# 631       40       80       40     65           5      False
# 46        35       30       40     55           1      False
# 695       70       65       70     58           5      False
# 794      121       81       95     95           6       True
#
# [800 rows x 13 columns]

# %% [markdown]
# **Sorting data into dscending order**

# %%
df.sort_values('Name', ascending = False)
# Out:
#        #                     Name   Type 1  Type 2  Total   HP  Attack  \
# 794  718         Zygarde50% Forme   Dragon  Ground    600  108     100
# 695  634                 Zweilous     Dark  Dragon    420   72      85
# 46    41                    Zubat   Poison  Flying    245   40      45
# 631  570                    Zorua     Dark     NaN    330   40      65
# 632  571                  Zoroark     Dark     NaN    510   60     105
# ..   ...                      ...      ...     ...    ...  ...     ...
# 393  359          AbsolMega Absol     Dark     NaN    565   65     150
# 392  359                    Absol     Dark     NaN    465   65     130
# 68    63                     Abra  Psychic     NaN    310   25      20
# 511  460  AbomasnowMega Abomasnow    Grass     Ice    594   90     132
# 510  460                Abomasnow    Grass     Ice    494   90      92
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 794      121       81       95     95           6       True
# 695       70       65       70     58           5      False
# 46        35       30       40     55           1      False
# 631       40       80       40     65           5      False
# 632       60      120       60    105           5      False
# ..       ...      ...      ...    ...         ...        ...
# 393       60      115       60    115           3      False
# 392       60       75       60     75           3      False
# 68        15      105       55     90           1      False
# 511      105      132      105     30           4      False
# 510       75       92       85     60           4      False
#
# [800 rows x 13 columns]

# %%
df.sort_values(['Name', 'Type 1', 'Type 2'], ascending = [1, 0, 1])
# Out:
#        #                     Name   Type 1  Type 2  Total   HP  Attack  \
# 510  460                Abomasnow    Grass     Ice    494   90      92
# 511  460  AbomasnowMega Abomasnow    Grass     Ice    594   90     132
# 68    63                     Abra  Psychic     NaN    310   25      20
# 392  359                    Absol     Dark     NaN    465   65     130
# 393  359          AbsolMega Absol     Dark     NaN    565   65     150
# ..   ...                      ...      ...     ...    ...  ...     ...
# 632  571                  Zoroark     Dark     NaN    510   60     105
# 631  570                    Zorua     Dark     NaN    330   40      65
# 46    41                    Zubat   Poison  Flying    245   40      45
# 695  634                 Zweilous     Dark  Dragon    420   72      85
# 794  718         Zygarde50% Forme   Dragon  Ground    600  108     100
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 510       75       92       85     60           4      False
# 511      105      132      105     30           4      False
# 68        15      105       55     90           1      False
# 392       60       75       60     75           3      False
# 393       60      115       60    115           3      False
# ..       ...      ...      ...    ...         ...        ...
# 632       60      120       60    105           5      False
# 631       40       80       40     65           5      False
# 46        35       30       40     55           1      False
# 695       70       65       70     58           5      False
# 794      121       81       95     95           6       True
#
# [800 rows x 13 columns]

# %% [markdown]
# **Making changes to the data**

# %%
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df['Sum'] = df['Total'] + df['HP'] + df['Attack']
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  Sum
# 0       65       65     45           1      False  412
# 1       80       80     60           1      False  527
# 2      100      100     80           1      False  687
# 3      122      120     80           1      False  805
# 4       60       50     65           1      False  400

# %%
df['Mul'] = df['HP'] * df['Attack']
df.tail(5)
# Out:
#        #                 Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 795  719              Diancie     Rock  Fairy    600  50     100      150
# 796  719  DiancieMega Diancie     Rock  Fairy    700  50     160      110
# 797  720  HoopaHoopa Confined  Psychic  Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic   Dark    680  80     160       60
# 799  721            Volcanion     Fire  Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Sum    Mul
# 795      100      150     50           6       True  750   5000
# 796      160      110    110           6       True  910   8000
# 797      150      130     70           6       True  790   8800
# 798      170      130     80           6       True  920  12800
# 799      130       90     70           6       True  790   8800

# %% [markdown]
# **Drop a column**

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary', 'Sum', 'Mul'],
#       dtype='object')

# %%
df = df.drop(columns=['Sum'])
df.head(3)
# Out:
#    #       Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1  Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2    Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3   Venusaur  Grass  Poison    525  80      82       83      100      100
#
#    Speed  Generation  Legendary   Mul
# 0     45           1      False  2205
# 1     60           1      False  3720
# 2     80           1      False  6560

# %% [markdown]
# **Alternative way to sum columns**

# %%
df['Sum2'] = df.iloc[:, 4:8].sum(axis=1)
df.head(3)
# Out:
#    #       Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1  Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2    Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3   Venusaur  Grass  Poison    525  80      82       83      100      100
#
#    Speed  Generation  Legendary   Mul  Sum2
# 0     45           1      False  2205   461
# 1     60           1      False  3720   590
# 2     80           1      False  6560   770

# %% [markdown]
# **Drop multiple columns**

# %%
df = df.drop(columns=['Sum2', 'Mul'])
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# **Filtering data**

# %% [markdown]
# **Sreach rows using valus**

# %%
df.loc[df['Type 1'] == 'Dark']
# Out:
#        #                   Name Type 1    Type 2  Total   HP  Attack  Defense  \
# 212  197                Umbreon   Dark       NaN    525   95      65      110
# 213  198                Murkrow   Dark    Flying    405   60      85       42
# 233  215                Sneasel   Dark       Ice    430   55      95       55
# 246  228               Houndour   Dark      Fire    330   45      60       30
# 247  229               Houndoom   Dark      Fire    500   75      90       50
# 248  229  HoundoomMega Houndoom   Dark      Fire    600   75      90       90
# 284  261              Poochyena   Dark       NaN    220   35      55       35
# 285  262              Mightyena   Dark       NaN    420   70      90       70
# 326  302                Sableye   Dark     Ghost    380   50      75       75
# 327  302    SableyeMega Sableye   Dark     Ghost    480   50      85      125
# 392  359                  Absol   Dark       NaN    465   65     130       60
# 393  359        AbsolMega Absol   Dark       NaN    565   65     150       60
# 478  430              Honchkrow   Dark    Flying    505  100     125       52
# 512  461                Weavile   Dark       Ice    510   70     120       65
# 549  491                Darkrai   Dark       NaN    600   70      90       90
# 568  509               Purrloin   Dark       NaN    281   41      50       37
# 569  510                Liepard   Dark       NaN    446   64      88       50
# 620  559                Scraggy   Dark  Fighting    348   50      75       70
# 621  560                Scrafty   Dark  Fighting    488   65      90      115
# 631  570                  Zorua   Dark       NaN    330   40      65       40
# 632  571                Zoroark   Dark       NaN    510   60     105       60
# 685  624               Pawniard   Dark     Steel    340   45      85       70
# 686  625                Bisharp   Dark     Steel    490   65     125      100
# 690  629                Vullaby   Dark    Flying    370   70      55       75
# 691  630              Mandibuzz   Dark    Flying    510  110      65      105
# 694  633                  Deino   Dark    Dragon    300   52      65       50
# 695  634               Zweilous   Dark    Dragon    420   72      85       70
# 696  635              Hydreigon   Dark    Dragon    600   92     105       90
# 756  686                  Inkay   Dark   Psychic    288   53      54       53
# 757  687                Malamar   Dark   Psychic    482   86      92       88
# 793  717                Yveltal   Dark    Flying    680  126     131       95
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 212       60      130     65           2      False
# 213       85       42     91           2      False
# 233       35       75    115           2      False
# 246       80       50     65           2      False
# 247      110       80     95           2      False
# 248      140       90    115           2      False
# 284       30       30     35           3      False
# 285       60       60     70           3      False
# 326       65       65     50           3      False
# 327       85      115     20           3      False
# 392       75       60     75           3      False
# 393      115       60    115           3      False
# 478      105       52     71           4      False
# 512       45       85    125           4      False
# 549      135       90    125           4       True
# 568       50       37     66           5      False
# 569       88       50    106           5      False
# 620       35       70     48           5      False
# 621       45      115     58           5      False
# 631       80       40     65           5      False
# 632      120       60    105           5      False
# 685       40       40     60           5      False
# 686       60       70     70           5      False
# 690       45       65     60           5      False
# 691       55       95     80           5      False
# 694       45       50     38           5      False
# 695       65       70     58           5      False
# 696      125       90     98           5      False
# 756       37       46     45           6      False
# 757       68       75     73           6      False
# 793      131       98     99           6       True

# %%
df.loc[df['Type 2'] == 'Fire']
# Out:
#        #                   Name    Type 1 Type 2  Total   HP  Attack  Defense  \
# 246  228               Houndour      Dark   Fire    330   45      60       30
# 247  229               Houndoom      Dark   Fire    500   75      90       50
# 248  229  HoundoomMega Houndoom      Dark   Fire    600   75      90       90
# 424  383  GroudonPrimal Groudon    Ground   Fire    770  100     180      160
# 532  479        RotomHeat Rotom  Electric   Fire    520   50      65      107
# 553  494                Victini   Psychic   Fire    600  100     100      100
# 668  607                Litwick     Ghost   Fire    275   50      30       55
# 669  608                Lampent     Ghost   Fire    370   60      40       60
# 670  609             Chandelure     Ghost   Fire    520   60      55       90
# 697  636               Larvesta       Bug   Fire    360   55      85       55
# 698  637              Volcarona       Bug   Fire    550   85      60       65
# 706  643               Reshiram    Dragon   Fire    680  100     120      100
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 246       80       50     65           2      False
# 247      110       80     95           2      False
# 248      140       90    115           2      False
# 424      150       90     90           3       True
# 532      105      107     86           4      False
# 553      100      100    100           5       True
# 668       65       55     20           5      False
# 669       95       60     55           5      False
# 670      145       90     80           5      False
# 697       50       55     60           5      False
# 698      135      105    100           5      False
# 706      150      120     90           5       True

# %% [markdown]
# **Search rows using multiple values**

# %%
df.loc[(df['Type 1'] == 'Bug') & (df['Type 2'] == 'Fire')]
# Out:
#        #       Name Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 697  636   Larvesta    Bug   Fire    360  55      85       55       50
# 698  637  Volcarona    Bug   Fire    550  85      60       65      135
#
#      Sp. Def  Speed  Generation  Legendary
# 697       55     60           5      False
# 698      105    100           5      False

# %%
df.loc[(df['Type 1'] == 'Dark') & (df['Type 2'] == 'Fire') & (df['HP'] > 20)]
# Out:
#        #                   Name Type 1 Type 2  Total  HP  Attack  Defense  \
# 246  228               Houndour   Dark   Fire    330  45      60       30
# 247  229               Houndoom   Dark   Fire    500  75      90       50
# 248  229  HoundoomMega Houndoom   Dark   Fire    600  75      90       90
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 246       80       50     65           2      False
# 247      110       80     95           2      False
# 248      140       90    115           2      False

# %%
df.loc[((df['Type 1'] == 'Dark') | (df['Type 2'] == 'Dark')) & (df['Total'] > 500)]
# Out:
#        #                     Name   Type 1  Type 2  Total   HP  Attack  \
# 141  130    GyaradosMega Gyarados    Water    Dark    640   95     155
# 212  197                  Umbreon     Dark     NaN    525   95      65
# 248  229    HoundoomMega Houndoom     Dark    Fire    600   75      90
# 267  248                Tyranitar     Rock    Dark    600  100     134
# 268  248  TyranitarMega Tyranitar     Rock    Dark    700  100     164
# 349  319    SharpedoMega Sharpedo    Water    Dark    560   70     140
# 393  359          AbsolMega Absol     Dark     NaN    565   65     150
# 478  430                Honchkrow     Dark  Flying    505  100     125
# 512  461                  Weavile     Dark     Ice    510   70     120
# 549  491                  Darkrai     Dark     NaN    600   70      90
# 613  553               Krookodile   Ground    Dark    519   95     117
# 632  571                  Zoroark     Dark     NaN    510   60     105
# 691  630                Mandibuzz     Dark  Flying    510  110      65
# 696  635                Hydreigon     Dark  Dragon    600   92     105
# 726  658                 Greninja    Water    Dark    530   72      95
# 793  717                  Yveltal     Dark  Flying    680  126     131
# 798  720       HoopaHoopa Unbound  Psychic    Dark    680   80     160
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 141      109       70      130     81           1      False
# 212      110       60      130     65           2      False
# 248       90      140       90    115           2      False
# 267      110       95      100     61           2      False
# 268      150       95      120     71           2      False
# 349       70      110       65    105           3      False
# 393       60      115       60    115           3      False
# 478       52      105       52     71           4      False
# 512       65       45       85    125           4      False
# 549       90      135       90    125           4       True
# 613       80       65       70     92           5      False
# 632       60      120       60    105           5      False
# 691      105       55       95     80           5      False
# 696       90      125       90     98           5      False
# 726       67      103       71    122           6      False
# 793       95      131       98     99           6       True
# 798       60      170      130     80           6       True

# %% [markdown]
# **Making new csv file**

# %%
df_new = df.loc[(df['Type 1'] == 'Dark') & (df['Type 2'] == 'Fire') & (df['HP'] > 10)]
df_new
#df_new.to_csv('New Pokemon')
# Out:
#        #                   Name Type 1 Type 2  Total  HP  Attack  Defense  \
# 246  228               Houndour   Dark   Fire    330  45      60       30
# 247  229               Houndoom   Dark   Fire    500  75      90       50
# 248  229  HoundoomMega Houndoom   Dark   Fire    600  75      90       90
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 246       80       50     65           2      False
# 247      110       80     95           2      False
# 248      140       90    115           2      False

# %%
df_new1 = df.loc[(df['Type 1'] == 'Dark') | (df['Defense'] >= 600)]
df_new1
# Out:
#        #                   Name Type 1    Type 2  Total   HP  Attack  Defense  \
# 212  197                Umbreon   Dark       NaN    525   95      65      110
# 213  198                Murkrow   Dark    Flying    405   60      85       42
# 233  215                Sneasel   Dark       Ice    430   55      95       55
# 246  228               Houndour   Dark      Fire    330   45      60       30
# 247  229               Houndoom   Dark      Fire    500   75      90       50
# 248  229  HoundoomMega Houndoom   Dark      Fire    600   75      90       90
# 284  261              Poochyena   Dark       NaN    220   35      55       35
# 285  262              Mightyena   Dark       NaN    420   70      90       70
# 326  302                Sableye   Dark     Ghost    380   50      75       75
# 327  302    SableyeMega Sableye   Dark     Ghost    480   50      85      125
# 392  359                  Absol   Dark       NaN    465   65     130       60
# 393  359        AbsolMega Absol   Dark       NaN    565   65     150       60
# 478  430              Honchkrow   Dark    Flying    505  100     125       52
# 512  461                Weavile   Dark       Ice    510   70     120       65
# 549  491                Darkrai   Dark       NaN    600   70      90       90
# 568  509               Purrloin   Dark       NaN    281   41      50       37
# 569  510                Liepard   Dark       NaN    446   64      88       50
# 620  559                Scraggy   Dark  Fighting    348   50      75       70
# 621  560                Scrafty   Dark  Fighting    488   65      90      115
# 631  570                  Zorua   Dark       NaN    330   40      65       40
# 632  571                Zoroark   Dark       NaN    510   60     105       60
# 685  624               Pawniard   Dark     Steel    340   45      85       70
# 686  625                Bisharp   Dark     Steel    490   65     125      100
# 690  629                Vullaby   Dark    Flying    370   70      55       75
# 691  630              Mandibuzz   Dark    Flying    510  110      65      105
# 694  633                  Deino   Dark    Dragon    300   52      65       50
# 695  634               Zweilous   Dark    Dragon    420   72      85       70
# 696  635              Hydreigon   Dark    Dragon    600   92     105       90
# 756  686                  Inkay   Dark   Psychic    288   53      54       53
# 757  687                Malamar   Dark   Psychic    482   86      92       88
# 793  717                Yveltal   Dark    Flying    680  126     131       95
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 212       60      130     65           2      False
# 213       85       42     91           2      False
# 233       35       75    115           2      False
# 246       80       50     65           2      False
# 247      110       80     95           2      False
# 248      140       90    115           2      False
# 284       30       30     35           3      False
# 285       60       60     70           3      False
# 326       65       65     50           3      False
# 327       85      115     20           3      False
# 392       75       60     75           3      False
# 393      115       60    115           3      False
# 478      105       52     71           4      False
# 512       45       85    125           4      False
# 549      135       90    125           4       True
# 568       50       37     66           5      False
# 569       88       50    106           5      False
# 620       35       70     48           5      False
# 621       45      115     58           5      False
# 631       80       40     65           5      False
# 632      120       60    105           5      False
# 685       40       40     60           5      False
# 686       60       70     70           5      False
# 690       45       65     60           5      False
# 691       55       95     80           5      False
# 694       45       50     38           5      False
# 695       65       70     58           5      False
# 696      125       90     98           5      False
# 756       37       46     45           6      False
# 757       68       75     73           6      False
# 793      131       98     99           6       True

# %% [markdown]
# **Searchibg by string values**

# %%
df.loc[df['Name'].str.contains('Houndoom')]
# Out:
#        #                   Name Type 1 Type 2  Total  HP  Attack  Defense  \
# 247  229               Houndoom   Dark   Fire    500  75      90       50
# 248  229  HoundoomMega Houndoom   Dark   Fire    600  75      90       90
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 247      110       80     95           2      False
# 248      140       90    115           2      False

# %%
df.loc[df['Name'].str.contains('ye')]
# Out:
#        #                 Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 284  261            Poochyena     Dark    NaN    220  35      55       35
# 285  262            Mightyena     Dark    NaN    420  70      90       70
# 326  302              Sableye     Dark  Ghost    380  50      75       75
# 327  302  SableyeMega Sableye     Dark  Ghost    480  50      85      125
# 666  605               Elgyem  Psychic    NaN    335  55      55       55
# 667  606             Beheeyem  Psychic    NaN    485  75      75       75
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 284       30       30     35           3      False
# 285       60       60     70           3      False
# 326       65       65     50           3      False
# 327       85      115     20           3      False
# 666       85       55     30           5      False
# 667      125       95     40           5      False

# %%
df.loc[df['Name'].str.contains('Sableye') & (df['Total'] > 390)]
# Out:
#        #                 Name Type 1 Type 2  Total  HP  Attack  Defense  \
# 327  302  SableyeMega Sableye   Dark  Ghost    480  50      85      125
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 327       85      115     20           3      False

# %%
df.loc[df['Name'].str.contains('Houndoom')]
# Out:
#        #                   Name Type 1 Type 2  Total  HP  Attack  Defense  \
# 247  229               Houndoom   Dark   Fire    500  75      90       50
# 248  229  HoundoomMega Houndoom   Dark   Fire    600  75      90       90
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 247      110       80     95           2      False
# 248      140       90    115           2      False

# %%
df.loc[~df['Name'].str.contains('Houndoom')][0:5]
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
import re
df.loc[df['Type 1'].str.contains('Grass|Ghost', regex = True)]
# Out:
#        #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass  Poison    318  45      49       49
# 1      2                Ivysaur  Grass  Poison    405  60      62       63
# 2      3               Venusaur  Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 48    43                 Oddish  Grass  Poison    320  45      50       55
# ..   ...                    ...    ...     ...    ...  ..     ...      ...
# 783  710    PumpkabooSuper Size  Ghost   Grass    335  59      66       70
# 784  711  GourgeistAverage Size  Ghost   Grass    494  65      90      122
# 785  711    GourgeistSmall Size  Ghost   Grass    494  55      85      122
# 786  711    GourgeistLarge Size  Ghost   Grass    494  75      95      122
# 787  711    GourgeistSuper Size  Ghost   Grass    494  85     100      122
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 48        75       65     30           1      False
# ..       ...      ...    ...         ...        ...
# 783       44       55     41           6      False
# 784       58       75     84           6      False
# 785       58       75     99           6      False
# 786       58       75     69           6      False
# 787       58       75     54           6      False
#
# [102 rows x 13 columns]

# %%
df.loc[df['Type 1'].str.contains('poison|flying', flags = re.I, regex=True)]
# Out:
#        #                     Name  Type 1    Type 2  Total   HP  Attack  \
# 28    23                    Ekans  Poison       NaN    288   35      60
# 29    24                    Arbok  Poison       NaN    438   60      85
# 34    29                 Nidoran♀  Poison       NaN    275   55      47
# 35    30                 Nidorina  Poison       NaN    365   70      62
# 36    31                Nidoqueen  Poison    Ground    505   90      92
# 37    32                 Nidoran♂  Poison       NaN    273   46      57
# 38    33                 Nidorino  Poison       NaN    365   61      72
# 39    34                 Nidoking  Poison    Ground    505   81     102
# 46    41                    Zubat  Poison    Flying    245   40      45
# 47    42                   Golbat  Poison    Flying    455   75      80
# 95    88                   Grimer  Poison       NaN    325   80      80
# 96    89                      Muk  Poison       NaN    500  105     105
# 117  109                  Koffing  Poison       NaN    340   40      65
# 118  110                  Weezing  Poison       NaN    490   65      90
# 183  169                   Crobat  Poison    Flying    535   85      90
# 345  316                   Gulpin  Poison       NaN    302   70      43
# 346  317                   Swalot  Poison       NaN    467  100      73
# 368  336                  Seviper  Poison       NaN    458   73     100
# 482  434                   Stunky  Poison      Dark    329   63      63
# 483  435                 Skuntank  Poison      Dark    479  103      93
# 501  451                  Skorupi  Poison       Bug    330   40      50
# 502  452                  Drapion  Poison      Dark    500   70      90
# 503  453                 Croagunk  Poison  Fighting    300   48      61
# 504  454                Toxicroak  Poison  Fighting    490   83     106
# 629  568                 Trubbish  Poison       NaN    329   50      50
# 630  569                 Garbodor  Poison       NaN    474   80      95
# 702  641  TornadusIncarnate Forme  Flying       NaN    580   79     115
# 703  641    TornadusTherian Forme  Flying       NaN    580   79     100
# 760  690                   Skrelp  Poison     Water    320   50      60
# 761  691                 Dragalge  Poison    Dragon    494   65      75
# 790  714                   Noibat  Flying    Dragon    245   40      30
# 791  715                  Noivern  Flying    Dragon    535   85      70
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 28        44       40       54     55           1      False
# 29        69       65       79     80           1      False
# 34        52       40       40     41           1      False
# 35        67       55       55     56           1      False
# 36        87       75       85     76           1      False
# 37        40       40       40     50           1      False
# 38        57       55       55     65           1      False
# 39        77       85       75     85           1      False
# 46        35       30       40     55           1      False
# 47        70       65       75     90           1      False
# 95        50       40       50     25           1      False
# 96        75       65      100     50           1      False
# 117       95       60       45     35           1      False
# 118      120       85       70     60           1      False
# 183       80       70       80    130           2      False
# 345       53       43       53     40           3      False
# 346       83       73       83     55           3      False
# 368       60      100       60     65           3      False
# 482       47       41       41     74           4      False
# 483       67       71       61     84           4      False
# 501       90       30       55     65           4      False
# 502      110       60       75     95           4      False
# 503       40       61       40     50           4      False
# 504       65       86       65     85           4      False
# 629       62       40       62     65           5      False
# 630       82       60       82     75           5      False
# 702       70      125       80    111           5       True
# 703       80      110       90    121           5       True
# 760       60       60       60     30           6      False
# 761       90       97      123     44           6      False
# 790       35       45       40     55           6      False
# 791       80       97       80    123           6      False

# %% [markdown]
# **Conditional changes**

# %%
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df.loc[df['Type 1'] == 'Grass', 'Type 1'] = 'Poison'
df.head(5)
# Out:
#    #                   Name  Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Poison  Poison    318  45      49       49
# 1  2                Ivysaur  Poison  Poison    405  60      62       63
# 2  3               Venusaur  Poison  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Poison  Poison    625  80     100      123
# 4  4             Charmander    Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df.loc[df['Type 1'] == 'Poison', 'Type 1'] = 'Grass'
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df.loc[df['HP'] >= 50, ['Total', 'Attack']] = 'Test0'
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total  HP Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45     49       49
# 1  2                Ivysaur  Grass  Poison  Test0  60  Test0       63
# 2  3               Venusaur  Grass  Poison  Test0  80  Test0       83
# 3  3  VenusaurMega Venusaur  Grass  Poison  Test0  80  Test0      123
# 4  4             Charmander   Fire     NaN    309  39     52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df.loc[df['Total'] == 'Test0', ['Total', 'Attack']] = [12, 45]
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison     12  60      45       63
# 2  3               Venusaur  Grass  Poison     12  80      45       83
# 3  3  VenusaurMega Venusaur  Grass  Poison     12  80      45      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df.loc[df['Total'] == 12, ['Total', 'Attack']] = [2, 5]
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison      2  60       5       63
# 2  3               Venusaur  Grass  Poison      2  80       5       83
# 3  3  VenusaurMega Venusaur  Grass  Poison      2  80       5      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# **Group by - mean**

# %%
df.groupby('Type 1').mean()
# Out:
#                    #       Total         HP     Attack     Defense    Sp. Atk  \
# Type 1
# Bug       334.492754   72.043478  56.884058  14.550725   70.724638  53.869565
# Dark      461.354839   50.096774  66.806452  14.354839   70.225806  74.645161
# Dragon    474.375000   39.875000  83.312500  13.000000   86.375000  96.843750
# Electric  363.500000   68.750000  59.795455  14.909091   66.295455  90.022727
# Fairy     449.529412   34.000000  74.117647   7.823529   65.705882  78.529412
# Fighting  363.851852   54.592593  69.851852  15.555556   65.925926  53.111111
# Fire      327.403846   48.961538  69.903846  12.365385   67.769231  88.980769
# Flying    677.750000   62.750000  70.750000  11.250000   66.250000  94.250000
# Ghost     486.500000  112.843750  64.437500  22.250000   81.187500  79.343750
# Grass     318.275510   56.918367  67.265306  12.785714   70.234694  72.622449
# Ground    356.281250   41.125000  73.781250  12.968750   84.843750  56.468750
# Ice       423.541667   40.916667  72.000000  10.000000   71.416667  77.541667
# Normal    319.173469   45.438776  77.275510  12.561224   59.846939  55.816327
# Psychic   380.807018   62.614035  70.631579  11.000000   67.684211  98.403509
# Rock      392.727273   64.840909  65.363636  14.977273  100.795455  63.340909
# Steel     442.851852   36.037037  65.222222  11.481481  126.370370  67.518519
# Water     303.089286   55.223214  72.062500  13.026786   72.946429  74.812500
#
#             Sp. Def       Speed  Generation  Legendary
# Type 1
# Bug       64.797101   61.681159    3.217391   0.000000
# Dark      69.516129   76.161290    4.032258   0.064516
# Dragon    88.843750   83.031250    3.875000   0.375000
# Electric  73.704545   84.500000    3.272727   0.090909
# Fairy     84.705882   48.588235    4.117647   0.058824
# Fighting  64.703704   66.074074    3.370370   0.000000
# Fire      72.211538   74.442308    3.211538   0.096154
# Flying    72.500000  102.500000    5.500000   0.500000
# Ghost     76.468750   64.343750    4.187500   0.062500
# Grass     68.704082   62.397959    3.122449   0.030612
# Ground    62.750000   63.906250    3.156250   0.125000
# Ice       76.291667   63.458333    3.541667   0.083333
# Normal    63.724490   71.551020    3.051020   0.020408
# Psychic   86.280702   81.491228    3.385965   0.245614
# Rock      75.477273   55.909091    3.454545   0.090909
# Steel     80.629630   55.259259    3.851852   0.148148
# Water     70.517857   65.964286    2.857143   0.035714

# %%
df.groupby('Type 1').mean().sort_values('HP', ascending = False)
# Out:
#                    #       Total         HP     Attack     Defense    Sp. Atk  \
# Type 1
# Dragon    474.375000   39.875000  83.312500  13.000000   86.375000  96.843750
# Normal    319.173469   45.438776  77.275510  12.561224   59.846939  55.816327
# Fairy     449.529412   34.000000  74.117647   7.823529   65.705882  78.529412
# Ground    356.281250   41.125000  73.781250  12.968750   84.843750  56.468750
# Water     303.089286   55.223214  72.062500  13.026786   72.946429  74.812500
# Ice       423.541667   40.916667  72.000000  10.000000   71.416667  77.541667
# Flying    677.750000   62.750000  70.750000  11.250000   66.250000  94.250000
# Psychic   380.807018   62.614035  70.631579  11.000000   67.684211  98.403509
# Fire      327.403846   48.961538  69.903846  12.365385   67.769231  88.980769
# Fighting  363.851852   54.592593  69.851852  15.555556   65.925926  53.111111
# Grass     318.275510   56.918367  67.265306  12.785714   70.234694  72.622449
# Dark      461.354839   50.096774  66.806452  14.354839   70.225806  74.645161
# Rock      392.727273   64.840909  65.363636  14.977273  100.795455  63.340909
# Steel     442.851852   36.037037  65.222222  11.481481  126.370370  67.518519
# Ghost     486.500000  112.843750  64.437500  22.250000   81.187500  79.343750
# Electric  363.500000   68.750000  59.795455  14.909091   66.295455  90.022727
# Bug       334.492754   72.043478  56.884058  14.550725   70.724638  53.869565
#
#             Sp. Def       Speed  Generation  Legendary
# Type 1
# Dragon    88.843750   83.031250    3.875000   0.375000
# Normal    63.724490   71.551020    3.051020   0.020408
# Fairy     84.705882   48.588235    4.117647   0.058824
# Ground    62.750000   63.906250    3.156250   0.125000
# Water     70.517857   65.964286    2.857143   0.035714
# Ice       76.291667   63.458333    3.541667   0.083333
# Flying    72.500000  102.500000    5.500000   0.500000
# Psychic   86.280702   81.491228    3.385965   0.245614
# Fire      72.211538   74.442308    3.211538   0.096154
# Fighting  64.703704   66.074074    3.370370   0.000000
# Grass     68.704082   62.397959    3.122449   0.030612
# Dark      69.516129   76.161290    4.032258   0.064516
# Rock      75.477273   55.909091    3.454545   0.090909
# Steel     80.629630   55.259259    3.851852   0.148148
# Ghost     76.468750   64.343750    4.187500   0.062500
# Electric  73.704545   84.500000    3.272727   0.090909
# Bug       64.797101   61.681159    3.217391   0.000000

# %%
df.groupby('Type 2').mean().sort_values('Attack', ascending = False)
# Out:
#                    #       Total         HP     Attack     Defense  \
# Type 2
# Bug       382.000000  229.000000  53.333333  50.000000   80.000000
# Grass     505.400000   73.280000  62.640000  18.000000   80.120000
# Water     400.000000   93.214286  62.714286  18.000000   85.071429
# Poison    169.970588   96.588235  58.764706  17.323529   59.558824
# Ghost     551.714286   41.785714  59.142857  16.428571   82.285714
# Steel     435.636364   61.636364  64.636364  13.727273  104.636364
# Normal    681.000000   73.750000  63.500000  13.250000   53.750000
# Flying    331.103093   44.938144  71.391753  11.185567   68.309278
# Fairy     379.043478   67.913043  64.304348  10.739130   73.869565
# Fire      481.833333   29.333333  71.250000   9.583333   80.166667
# Ground    307.600000   29.000000  77.228571   9.428571   90.314286
# Psychic   337.151515   37.666667  72.212121   9.393939   87.030303
# Dark      413.850000   17.150000  75.550000   9.250000   72.050000
# Fighting  438.192308   13.461538  79.461538   7.153846   82.500000
# Dragon    482.555556   15.500000  82.166667   6.388889   87.055556
# Rock      347.785714   37.928571  68.071429   5.357143  126.857143
# Electric  465.666667    2.000000  88.166667   5.000000   68.333333
# Ice       441.285714    2.000000  90.000000   5.000000   85.642857
#
#              Sp. Atk    Sp. Def      Speed  Generation  Legendary
# Type 2
# Bug        46.666667  61.666667  61.666667    3.333333   0.000000
# Grass      60.160000  74.520000  57.320000    4.480000   0.000000
# Water      74.500000  68.642857  57.142857    3.428571   0.071429
# Poison     74.029412  69.911765  66.647059    1.970588   0.000000
# Ghost      73.214286  78.071429  53.857143    4.785714   0.071429
# Steel      77.727273  86.272727  59.363636    3.818182   0.045455
# Normal     88.000000  64.250000  89.250000    6.000000   0.000000
# Flying     75.628866  71.206186  85.721649    3.072165   0.134021
# Fairy      75.000000  81.956522  61.217391    3.565217   0.086957
# Fire      110.416667  83.500000  79.666667    4.000000   0.250000
# Ground     65.542857  66.742857  54.657143    2.942857   0.028571
# Psychic    88.030303  87.606061  69.484848    2.939394   0.151515
# Dark       81.800000  69.850000  75.350000    3.750000   0.050000
# Fighting   81.269231  82.384615  87.384615    3.923077   0.153846
# Dragon     98.500000  83.444444  80.555556    4.166667   0.222222
# Rock       51.142857  68.571429  36.000000    3.142857   0.000000
# Electric   81.166667  73.500000  71.500000    4.000000   0.166667
# Ice        92.642857  84.785714  74.642857    3.714286   0.214286

# %% [markdown]
# **Group by - sum**

# %%
df.groupby('Type 1').sum()
# Out:
#               #  Total    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 1
# Bug       23080   4971  3925    1004     4880     3717     4471   4256
# Dark      14302   1553  2071     445     2177     2314     2155   2361
# Dragon    15180   1276  2666     416     2764     3099     2843   2657
# Electric  15994   3025  2631     656     2917     3961     3243   3718
# Fairy      7642    578  1260     133     1117     1335     1440    826
# Fighting   9824   1474  1886     420     1780     1434     1747   1784
# Fire      17025   2546  3635     643     3524     4627     3755   3871
# Flying     2711    251   283      45      265      377      290    410
# Ghost     15568   3611  2062     712     2598     2539     2447   2059
# Grass     31191   5578  6592    1253     6883     7117     6733   6115
# Ground    11401   1316  2361     415     2715     1807     2008   2045
# Ice       10165    982  1728     240     1714     1861     1831   1523
# Normal    31279   4453  7573    1231     5865     5470     6245   7012
# Psychic   21706   3569  4026     627     3858     5609     4918   4645
# Rock      17280   2853  2876     659     4435     2787     3321   2460
# Steel     11957    973  1761     310     3412     1823     2177   1492
# Water     33946   6185  8071    1459     8170     8379     7898   7388
#
#           Generation  Legendary
# Type 1
# Bug              222        0.0
# Dark             125        2.0
# Dragon           124       12.0
# Electric         144        4.0
# Fairy             70        1.0
# Fighting          91        0.0
# Fire             167        5.0
# Flying            22        2.0
# Ghost            134        2.0
# Grass            306        3.0
# Ground           101        4.0
# Ice               85        2.0
# Normal           299        2.0
# Psychic          193       14.0
# Rock             152        4.0
# Steel            104        4.0
# Water            320        4.0

# %% [markdown]
# **Group by - count**

# %%
df.groupby('Type 1').count()
# Out:
#             #  Name  Type 2  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Type 1
# Bug        69    69      52     69   69      69       69       69       69
# Dark       31    31      21     31   31      31       31       31       31
# Dragon     32    32      21     32   32      32       32       32       32
# Electric   44    44      17     44   44      44       44       44       44
# Fairy      17    17       2     17   17      17       17       17       17
# Fighting   27    27       7     27   27      27       27       27       27
# Fire       52    52      24     52   52      52       52       52       52
# Flying      4     4       2      4    4       4        4        4        4
# Ghost      32    32      22     32   32      32       32       32       32
# Grass      98    98      50     98   98      98       98       98       98
# Ground     32    32      19     32   32      32       32       32       32
# Ice        24    24      11     24   24      24       24       24       24
# Normal     98    98      37     98   98      98       98       98       98
# Psychic    57    57      19     57   57      57       57       57       57
# Rock       44    44      35     44   44      44       44       44       44
# Steel      27    27      22     27   27      27       27       27       27
# Water     112   112      53    112  112     112      112      112      112
#
#           Speed  Generation  Legendary
# Type 1
# Bug          69          69         69
# Dark         31          31         31
# Dragon       32          32         32
# Electric     44          44         44
# Fairy        17          17         17
# Fighting     27          27         27
# Fire         52          52         52
# Flying        4           4          4
# Ghost        32          32         32
# Grass        98          98         98
# Ground       32          32         32
# Ice          24          24         24
# Normal       98          98         98
# Psychic      57          57         57
# Rock         44          44         44
# Steel        27          27         27
# Water       112         112        112

# %%
df['Count'] = 1
df.groupby(['Type 1']).count()['Count']
# Out:
# Type 1
# Bug          69
# Dark         31
# Dragon       32
# Electric     44
# Fairy        17
# Fighting     27
# Fire         52
# Flying        4
# Ghost        32
# Grass        98
# Ground       32
# Ice          24
# Normal       98
# Psychic      57
# Rock         44
# Steel        27
# Water       112
# Name: Count, dtype: int64

# %%
df['Count'] = 1
df.groupby(['Type 1', 'Type 2']).count()['Count']
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: Count, Length: 131, dtype: int64

# %% [markdown]
# **To be countinued...!**
